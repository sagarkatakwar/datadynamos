# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/Weather_london_preprocess.csv')
df.head()
# Out:
#                                             date       date_id   wind  \
# 0    Friday, January 1, 2021, 12:00 am — 6:00 am  1.609459e+12  4.971
# 1    Friday, January 1, 2021, 6:00 am — 12:00 pm  1.609481e+12  4.971
# 2    Friday, January 1, 2021, 12:00 pm — 6:00 pm  1.609502e+12  4.350
# 3    Friday, January 1, 2021, 6:00 pm — 12:00 am  1.609524e+12  4.971
# 4  Saturday, January 2, 2021, 12:00 am — 6:00 am  1.609546e+12  7.457
#
#                    desc  temp   baro  hum
# 0           Low clouds.  32.0  29.82   99
# 1           Low clouds.  33.8  29.86   94
# 2  Drizzle. Low clouds.  37.4  29.87   96
# 3           Low clouds.  39.2  29.93   96
# 4           Low clouds.  39.2  29.97   92

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("/content/Weather_london_preprocess.csv")

# Split and extract components from the 'date' column (assuming date format is consistent)
df[['day', 'month', 'date', 'year', 'time_range']] = df['date'].str.extract(
    r'^(.*?)(?:\s+)(\w+)(?:\s+)(\d+),\s+(\d{4}),\s+(.*)$'
)

# Clean up the extracted 'month' and 'date' columns
df['month'] = df['month'].str.strip()
df['date'] = df['date'].astype(int)

# The new 'date' column now contains just the date number, while 'month' contains the month's name
# The 'year' and 'time_range' will remain as separate columns

# Rearrange the columns for easier reading
df = df[['day', 'month', 'date', 'year', 'time_range', 'date_id', 'wind', 'desc', 'temp', 'baro', 'hum']]

# %%
df
# Out:
#             day     month  date  year          time_range       date_id  \
# 0       Friday,   January     1  2021  12:00 am — 6:00 am  1.609459e+12
# 1       Friday,   January     1  2021  6:00 am — 12:00 pm  1.609481e+12
# 2       Friday,   January     1  2021  12:00 pm — 6:00 pm  1.609502e+12
# 3       Friday,   January     1  2021  6:00 pm — 12:00 am  1.609524e+12
# 4     Saturday,   January     2  2021  12:00 am — 6:00 am  1.609546e+12
# ...         ...       ...   ...   ...                 ...           ...
# 1455  Thursday,  December    30  2021  6:00 pm — 12:00 am  1.640887e+12
# 1456    Friday,  December    31  2021  12:00 am — 6:00 am  1.640909e+12
# 1457    Friday,  December    31  2021  6:00 am — 12:00 pm  1.640930e+12
# 1458    Friday,  December    31  2021  12:00 pm — 6:00 pm  1.640952e+12
# 1459    Friday,  December    31  2021  6:00 pm — 12:00 am  1.640974e+12
#
#         wind                  desc  temp   baro  hum
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/content/Weather_london_preprocess.csv")

# Check the first few rows of the dataframe to understand its structure
print(df.head())
print(df.columns)  # To verify the columns, including 'date_id'

# If the 'date' column exists, then extract components
if 'date' in df.columns:
    df[['day', 'month', 'date', 'year', 'time_range']] = df['date'].str.extract(
        r'^(.*?)(?:\s+)(\w+)(?:\s+)(\d+),\s+(\d{4}),\s+(.*)$'
    )

    # Clean up the extracted columns
    df['month'] = df['month'].str.strip()
    df['date'] = df['date'].astype(int)

    # Check if 'day' was successfully extracted
    print(df.head())

    # Further cleaning and rearranging
    df['day'] = df['day'].str.replace(',', '', regex=False)

    # Convert 'date_id' column to string before using .str.replace()
    df['date_id'] = df['date_id'].astype(str).str.replace('+', '', regex=False)

    # Convert temp to Fahrenheit
    df['temp'] = (df['temp'] * 9/5) + 32

    # Reorder columns
    df = df[['day', 'month', 'date', 'year', 'time_range', 'date_id', 'wind', 'desc', 'temp', 'baro', 'hum']]
# Out:
#                                             date       date_id   wind  \
# 0    Friday, January 1, 2021, 12:00 am — 6:00 am  1.609459e+12  4.971
# 1    Friday, January 1, 2021, 6:00 am — 12:00 pm  1.609481e+12  4.971
# 2    Friday, January 1, 2021, 12:00 pm — 6:00 pm  1.609502e+12  4.350
# 3    Friday, January 1, 2021, 6:00 pm — 12:00 am  1.609524e+12  4.971
# 4  Saturday, January 2, 2021, 12:00 am — 6:00 am  1.609546e+12  7.457
#
#                    desc  temp   baro  hum
# 0           Low clouds.  32.0  29.82   99
# 1           Low clouds.  33.8  29.86   94
# 2  Drizzle. Low clouds.  37.4  29.87   96
# 3           Low clouds.  39.2  29.93   96
# 4           Low clouds.  39.2  29.97   92
# Index(['date', 'date_id', 'wind', 'desc', 'temp', 'baro', 'hum'], dtype='object')
#    date       date_id   wind                  desc  temp   baro  hum  \
# 0     1  1.609459e+12  4.971           Low clouds.  32.0  29.82   99
# ...

# %%
df
# Out:
#            day     month  date  year          time_range          date_id  \
# 0       Friday   January     1  2021  12:00 am — 6:00 am  1609459200000.0
# 1       Friday   January     1  2021  6:00 am — 12:00 pm  1609480800000.0
# 2       Friday   January     1  2021  12:00 pm — 6:00 pm  1609502400000.0
# 3       Friday   January     1  2021  6:00 pm — 12:00 am  1609524000000.0
# 4     Saturday   January     2  2021  12:00 am — 6:00 am  1609545600000.0
# ...        ...       ...   ...   ...                 ...              ...
# 1455  Thursday  December    30  2021  6:00 pm — 12:00 am  1640887200000.0
# 1456    Friday  December    31  2021  12:00 am — 6:00 am  1640908800000.0
# 1457    Friday  December    31  2021  6:00 am — 12:00 pm  1640930400000.0
# 1458    Friday  December    31  2021  12:00 pm — 6:00 pm  1640952000000.0
# 1459    Friday  December    31  2021  6:00 pm — 12:00 am  1640973600000.0
#
#         wind                  desc    temp   baro  hum
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("/content/Weather_london_preprocess.csv")

# Split and extract components from the 'date' column (assuming date format is consistent)
df[['day', 'month', 'date', 'year', 'time_range']] = df['date'].str.extract(
    r'^(.*?)(?:\s+)(\w+)(?:\s+)(\d+),\s+(\d{4}),\s+(.*)$'
)

# Clean up the extracted 'month' and 'date' columns
df['month'] = df['month'].str.strip()
df['date'] = df['date'].astype(int)

# Remove the comma in the 'day' column
df['day'] = df['day'].str.replace(',', '', regex=False)

# Remove the '+' sign from the 'date_id' column
df['date_id'] = df['date_id'].astype(str).str.replace('+', '', regex=False)

# Rearrange the columns for easier reading
df = df[['day', 'month', 'date', 'year', 'time_range', 'date_id', 'wind', 'desc', 'temp', 'baro', 'hum']]


# Output the first few rows to verify the changes
print(df.head())
# Out:
#         day    month  date  year          time_range          date_id   wind  \
# 0    Friday  January     1  2021  12:00 am — 6:00 am  1609459200000.0  4.971
# 1    Friday  January     1  2021  6:00 am — 12:00 pm  1609480800000.0  4.971
# 2    Friday  January     1  2021  12:00 pm — 6:00 pm  1609502400000.0  4.350
# 3    Friday  January     1  2021  6:00 pm — 12:00 am  1609524000000.0  4.971
# 4  Saturday  January     2  2021  12:00 am — 6:00 am  1609545600000.0  7.457
#
#                    desc  temp   baro  hum
# 0           Low clouds.  32.0  29.82   99
# 1           Low clouds.  33.8  29.86   94
# 2  Drizzle. Low clouds.  37.4  29.87   96
# 3           Low clouds.  39.2  29.93   96
# 4           Low clouds.  39.2  29.97   92

# %%
df
# Out:
#            day     month  date  year          time_range          date_id  \
# 0       Friday   January     1  2021  12:00 am — 6:00 am  1609459200000.0
# 1       Friday   January     1  2021  6:00 am — 12:00 pm  1609480800000.0
# 2       Friday   January     1  2021  12:00 pm — 6:00 pm  1609502400000.0
# 3       Friday   January     1  2021  6:00 pm — 12:00 am  1609524000000.0
# 4     Saturday   January     2  2021  12:00 am — 6:00 am  1609545600000.0
# ...        ...       ...   ...   ...                 ...              ...
# 1455  Thursday  December    30  2021  6:00 pm — 12:00 am  1640887200000.0
# 1456    Friday  December    31  2021  12:00 am — 6:00 am  1640908800000.0
# 1457    Friday  December    31  2021  6:00 am — 12:00 pm  1640930400000.0
# 1458    Friday  December    31  2021  12:00 pm — 6:00 pm  1640952000000.0
# 1459    Friday  December    31  2021  6:00 pm — 12:00 am  1640973600000.0
#
#         wind                  desc  temp   baro  hum
# ...

# %%
# Check for non-numeric entries in the 'wind' column
print(df[pd.to_numeric(df['wind'], errors='coerce').isna()])
# Out:
# Empty DataFrame
# Columns: [day, month, date, year, time_range, date_id, wind, desc, temp, baro, hum]
# Index: []

# %%
# Fill NaN values with a placeholder (e.g., 0) or drop them
df['wind'] = pd.to_numeric(df['wind'], errors='coerce')
df['wind'] = df['wind'].fillna(0)  # Fills NaN values with 0, can be adjusted based on requirements

# %%
#HERE IS THE CORRECTED CODE BELOW..THE DATA IS FULL CLEANED

# %%
df
# Out:
#            day     month  date  year          time_range          date_id  \
# 0       Friday   January     1  2021  12:00 am — 6:00 am  1609459200000.0
# 1       Friday   January     1  2021  6:00 am — 12:00 pm  1609480800000.0
# 2       Friday   January     1  2021  12:00 pm — 6:00 pm  1609502400000.0
# 3       Friday   January     1  2021  6:00 pm — 12:00 am  1609524000000.0
# 4     Saturday   January     2  2021  12:00 am — 6:00 am  1609545600000.0
# ...        ...       ...   ...   ...                 ...              ...
# 1455  Thursday  December    30  2021  6:00 pm — 12:00 am  1640887200000.0
# 1456    Friday  December    31  2021  12:00 am — 6:00 am  1640908800000.0
# 1457    Friday  December    31  2021  6:00 am — 12:00 pm  1640930400000.0
# 1458    Friday  December    31  2021  12:00 pm — 6:00 pm  1640952000000.0
# 1459    Friday  December    31  2021  6:00 pm — 12:00 am  1640973600000.0
#
#         wind                  desc  temp   baro  hum
# ...

# %%
df['temp'] = (df['temp'] - 32) * 5/9  # Convert Fahrenheit to Celsius

# Verify the new temperature range
print("Updated Temperature range (°C):", df['temp'].min(), "to", df['temp'].max())
# Out:
# Updated Temperature range (°C): -2.999999999999999 to 31.0

# %%
df
# Out:
#            day     month  date  year          time_range       date_id  \
# 0       Friday   January     1  2021  12:00 am — 6:00 am  1.609459e+12
# 1       Friday   January     1  2021  6:00 am — 12:00 pm  1.609481e+12
# 2       Friday   January     1  2021  12:00 pm — 6:00 pm  1.609502e+12
# 3       Friday   January     1  2021  6:00 pm — 12:00 am  1.609524e+12
# 4     Saturday   January     2  2021  12:00 am — 6:00 am  1.609546e+12
# ...        ...       ...   ...   ...                 ...           ...
# 1455  Thursday  December    30  2021  6:00 pm — 12:00 am  1.640887e+12
# 1456    Friday  December    31  2021  12:00 am — 6:00 am  1.640909e+12
# 1457    Friday  December    31  2021  6:00 am — 12:00 pm  1.640930e+12
# 1458    Friday  December    31  2021  12:00 pm — 6:00 pm  1.640952e+12
# 1459    Friday  December    31  2021  6:00 pm — 12:00 am  1.640974e+12
#
#         wind                  desc  temp   baro  hum  hour
# ...

# %%
# Save the cleaned data to a new CSV file
df.to_csv("/content/Weather_london_cleaned.csv", index=False)

# %%
df
# Out:
#            day     month  date  year          time_range       date_id  \
# 0       Friday   January     1  2021  12:00 am — 6:00 am  1.609459e+12
# 1       Friday   January     1  2021  6:00 am — 12:00 pm  1.609481e+12
# 2       Friday   January     1  2021  12:00 pm — 6:00 pm  1.609502e+12
# 3       Friday   January     1  2021  6:00 pm — 12:00 am  1.609524e+12
# 4     Saturday   January     2  2021  12:00 am — 6:00 am  1.609546e+12
# ...        ...       ...   ...   ...                 ...           ...
# 1455  Thursday  December    30  2021  6:00 pm — 12:00 am  1.640887e+12
# 1456    Friday  December    31  2021  12:00 am — 6:00 am  1.640909e+12
# 1457    Friday  December    31  2021  6:00 am — 12:00 pm  1.640930e+12
# 1458    Friday  December    31  2021  12:00 pm — 6:00 pm  1.640952e+12
# 1459    Friday  December    31  2021  6:00 pm — 12:00 am  1.640974e+12
#
#         wind                  desc  temp   baro  hum  hour
# ...

# %%
df.dtypes
# Out:
# day            object
# month          object
# date            int64
# year            int64
# time_range     object
# date_id       float64
# wind          float64
# desc           object
# temp          float64
# baro          float64
# hum             int64
# hour            int64
# dtype: object

# %%
df.describe()
# Out:
#               date    year       date_id         wind         temp  \
# count  1460.000000  1460.0  1.460000e+03  1460.000000  1460.000000
# mean     15.720548  2021.0  1.625216e+12     8.446125    12.763699
# std       8.799261     0.0  9.106776e+09     4.419983     6.432945
# min       1.000000  2021.0  1.609459e+12     0.621000    -3.000000
# 25%       8.000000  2021.0  1.617338e+12     4.971000     8.000000
# 50%      16.000000  2021.0  1.625216e+12     8.078000    13.000000
# 75%      23.000000  2021.0  1.633095e+12    11.185000    17.000000
# max      31.000000  2021.0  1.640974e+12    27.964000    31.000000
#
#               baro          hum         hour
# count  1460.000000  1460.000000  1460.000000
# mean     29.991637    78.185616     9.000000
# std       0.349570    14.108575     3.001028
# min      26.720000    27.000000     6.000000
# 25%      29.797500    70.000000     6.000000
# 50%      30.040000    81.000000     9.000000
# ...

# %%
df.isnull().sum()
# Out:
# day           0
# month         0
# date          0
# year          0
# time_range    0
# date_id       0
# wind          0
# desc          0
# temp          0
# baro          0
# hum           0
# hour          0
# dtype: int64

# %%
##DOING THE VISULIZATIONS NOW

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned dataset
df = pd.read_csv("/content/Weather_london_cleaned.csv")

# Plot temperature (°F) over time ranges using a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='time_range', y='temp', data=df, marker='o', color='b')
plt.title('Temperature Over Time Ranges')
plt.xlabel('Time Range')
plt.ylabel('Temperature (°F)')
plt.xticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()

# %%
# Plot wind speed across time ranges using a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='time_range', y='wind', data=df, palette="Blues")
plt.title('Wind Speed Across Time Ranges')
plt.xlabel('Time Range')
plt.ylabel('Wind Speed (m/s)')
plt.xticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-95-d8e9d3d31271>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='time_range', y='wind', data=df, palette="Blues")

# %%
# Plot humidity levels across time ranges using a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='time_range', y='hum', data=df, palette="Greens")
plt.title('Humidity Levels Across Time Ranges')
plt.xlabel('Time Range')
plt.ylabel('Humidity (%)')
plt.xticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-96-a6680d46191e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='time_range', y='hum', data=df, palette="Greens")

# %%
# Plot a histogram to show the distribution of wind speeds
plt.figure(figsize=(10, 6))
sns.histplot(df['wind'], kde=True, color='red', bins=15)
plt.title('Distribution of Wind Speed')
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Frequency')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Plot a histogram for temperature distribution (°F)
plt.figure(figsize=(10, 6))
sns.histplot(df['temp'], kde=True, color='orange', bins=15)
plt.title('Temperature Distribution')
plt.xlabel('Temperature (°F)')
plt.ylabel('Frequency')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Calculate correlations between numeric columns and visualize using a heatmap
plt.figure(figsize=(10, 6))
corr_matrix = df[['wind', 'temp', 'baro', 'hum']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Plot the average temperature for each day of the week using a bar plot
average_temp = df.groupby('day')['temp'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x='day', y='temp', data=average_temp, palette='coolwarm')
plt.title('Average Temperature for Each Day of the Week')
plt.xlabel('Day')
plt.ylabel('Average Temperature (°F)')
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-100-10b9003caf77>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day', y='temp', data=average_temp, palette='coolwarm')

# %%
# Scatter plot to show the relationship between temperature and wind speed
plt.figure(figsize=(12, 6))
sns.scatterplot(x='temp', y='wind', data=df, hue='day', palette='tab10')
plt.title('Temperature vs Wind Speed')
plt.xlabel('Temperature (°F)')
plt.ylabel('Wind Speed (m/s)')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Scatter plot to show the relationship between temperature and humidity
plt.figure(figsize=(12, 6))
sns.scatterplot(x='temp', y='hum', data=df, hue='day', palette='muted')
plt.title('Temperature vs Humidity')
plt.xlabel('Temperature (°F)')
plt.ylabel('Humidity (%)')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Box plot to show the distribution of temperature across days
plt.figure(figsize=(12, 6))
sns.boxplot(x='day', y='temp', data=df, palette='Set2')
plt.title('Temperature Distribution Across Days')
plt.xlabel('Day')
plt.ylabel('Temperature (°F)')
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-103-d95fc382fa8d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y='temp', data=df, palette='Set2')

# %%
# Box plot showing how the temperature varies across different time ranges
plt.figure(figsize=(12, 6))
sns.boxplot(x='time_range', y='temp', data=df, palette='viridis')
plt.title('Temperature Distribution Across Time of Day')
plt.xlabel('Time Range')
plt.ylabel('Temperature (°F)')
plt.xticks(rotation=45)
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-104-d83444a952e6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='time_range', y='temp', data=df, palette='viridis')

# %%
# Plot a histogram for the distribution of humidity levels
plt.figure(figsize=(10, 6))
sns.histplot(df['hum'], kde=True, color='purple', bins=15)
plt.title('Humidity Distribution')
plt.xlabel('Humidity (%)')
plt.ylabel('Frequency')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Plot the average wind speed by day of the week
average_wind = df.groupby('day')['wind'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x='day', y='wind', data=average_wind, palette='Blues_d')
plt.title('Average Wind Speed by Day')
plt.xlabel('Day')
plt.ylabel('Average Wind Speed (m/s)')
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-106-c9a8b702991a>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day', y='wind', data=average_wind, palette='Blues_d')

# %%
# Scatter plot to show the relationship between temperature and barometric pressure
plt.figure(figsize=(12, 6))
sns.scatterplot(x='temp', y='baro', data=df, hue='month', palette='coolwarm')
plt.title('Temperature vs Barometric Pressure')
plt.xlabel('Temperature (°F)')
plt.ylabel('Barometric Pressure (inHg)')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Plot hourly temperature changes by converting 'time_range' to numerical hours
df['hour'] = df['time_range'].str.extract(r'(\d{1,2})').astype(int)

plt.figure(figsize=(12, 6))
sns.lineplot(x='hour', y='temp', data=df, marker='o', color='green')
plt.title('Hourly Temperature Changes')
plt.xlabel('Hour of Day')
plt.ylabel('Temperature (°F)')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Scatter plot showing the relationship between wind speed and barometric pressure
plt.figure(figsize=(12, 6))
sns.scatterplot(x='wind', y='baro', data=df, hue='day', palette='Set1')
plt.title('Wind Speed vs Barometric Pressure')
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Barometric Pressure (inHg)')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Calculate the average temperature and wind speed across days and plot it
average_temp_wind = df.groupby('day')[['temp', 'wind']].mean().reset_index()
average_temp_wind = pd.melt(average_temp_wind, id_vars=['day'], value_vars=['temp', 'wind'], var_name='Measure', value_name='Value')

plt.figure(figsize=(12, 6))
sns.barplot(x='day', y='Value', hue='Measure', data=average_temp_wind, palette='Paired')
plt.title('Average Temperature and Wind Speed Across Days')
plt.xlabel('Day')
plt.ylabel('Value')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Pivot the data for a heatmap of temperature variation across days and time of day
temp_pivot = df.pivot_table(index='time_range', columns='day', values='temp', aggfunc='mean')

plt.figure(figsize=(12, 6))
sns.heatmap(temp_pivot, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Temperature Variation Across Days and Time of Day')
plt.xlabel('Day')
plt.ylabel('Time Range')
plt.tight_layout()

# Show plot
plt.show()

# %%
# Violin plot to show the distribution of wind speed across days
plt.figure(figsize=(12, 6))
sns.violinplot(x='day', y='wind', data=df, palette='Set3')
plt.title('Wind Speed Distribution Across Days')
plt.xlabel('Day')
plt.ylabel('Wind Speed (m/s)')
plt.tight_layout()

# Show plot
plt.show()
# Out:
# <ipython-input-112-2a49a1b59b6e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='day', y='wind', data=df, palette='Set3')

# %%
df
# Out:
#            day     month  date  year          time_range       date_id  \
# 0       Friday   January     1  2021  12:00 am — 6:00 am  1.609459e+12
# 1       Friday   January     1  2021  6:00 am — 12:00 pm  1.609481e+12
# 2       Friday   January     1  2021  12:00 pm — 6:00 pm  1.609502e+12
# 3       Friday   January     1  2021  6:00 pm — 12:00 am  1.609524e+12
# 4     Saturday   January     2  2021  12:00 am — 6:00 am  1.609546e+12
# ...        ...       ...   ...   ...                 ...           ...
# 1455  Thursday  December    30  2021  6:00 pm — 12:00 am  1.640887e+12
# 1456    Friday  December    31  2021  12:00 am — 6:00 am  1.640909e+12
# 1457    Friday  December    31  2021  6:00 am — 12:00 pm  1.640930e+12
# 1458    Friday  December    31  2021  12:00 pm — 6:00 pm  1.640952e+12
# 1459    Friday  December    31  2021  6:00 pm — 12:00 am  1.640974e+12
#
#         wind                  desc  temp   baro  hum  hour
# ...
